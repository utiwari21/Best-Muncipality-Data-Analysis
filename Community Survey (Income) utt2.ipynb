# %% [markdown]
# **Community Survery (Income)**
#
# Now we will see which community contains the highest earners. This analysis will help us identify the top communities through top earners.

# %%
#importing and displaying the file
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

survey = pd.read_csv("Community Survey.csv",low_memory=False)
survey.head()
# Out:
#    Respondent_ID               Start_Date language zip_code      municipality  \
# 0   118507525303  2024-01-07 15:27:56.000       en    15235  Wilkins Township
# 1   118507226179  2024-01-06 20:35:04.000       en    15220        Pittsburgh
# 2   118507527021  2024-01-07 15:33:35.000       en    15104  Braddock Borough
# 3   118506956404  2024-01-06 10:38:05.000       en    15220        Pittsburgh
# 4   118506950110  2024-01-06 10:25:42.000       en    15217        Pittsburgh
#
#            age gender                                income  \
# 0        35-44  Woman  I prefer not to answer this question
# 1  75 or older  Woman                  $100,000 to $149,999
# 2        35-44  Woman                     Less than $25,000
# 3        35-44    Man  I prefer not to answer this question
# 4        18-24    Man                    $25,000 to $39,999
#
#                               race_hisp                               lgbtqia  \
# 0  I prefer not to answer this question                                    No
# 1                           Multiracial                                   Yes
# 2             Black or African American                                   Yes
# 3  I prefer not to answer this question  I prefer not to answer this question
# 4                                 Other                                   Yes
#
#    ... arabic_langathome hindi_langathome swahili_langathome  \
# 0  ...               NaN              NaN                NaN
# 1  ...               NaN              NaN                NaN
# 2  ...               NaN              NaN                NaN
# 3  ...               NaN              NaN                NaN
# 4  ...               NaN              NaN                NaN
#
#   french_langathome german_langathome portuguese_langathome asl_langathome  \
# 0               NaN               NaN                   NaN            NaN
# 1               NaN               NaN                   NaN            NaN
# 2               NaN               NaN                   NaN            NaN
# 3               NaN               NaN                   NaN            NaN
# 4               NaN               NaN                   NaN            NaN
#
#   other_langathome no_languages_athome non-english_at_home
# 0              NaN                 0.0                  No
# 1              NaN                 0.0                  No
# 2              NaN                 0.0                  No
# 3              NaN                 0.0                  No
# 4              NaN                 0.0                  No
#
# [5 rows x 230 columns]

# %%
# Total respondents per municipality
total_respondents = survey['municipality'].value_counts()

# High-income respondents per municipality
high_income_respondents = seventy_five['municipality'].value_counts()

# Normalize by dividing high-income counts by total respondents
normalized_proportions = (high_income_respondents / total_respondents) * 100

# Sort by proportion and display the top 10 municipalities
top_normalized_cities = normalized_proportions.sort_values(ascending=False).head(10)

# Display results
print(top_normalized_cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 total_respondents = survey['municipality'].value_counts()
#       4 # High-income respondents per municipality
# ----> 5 high_income_respondents = seventy_five['municipality'].value_counts()
#       7 # Normalize by dividing high-income counts by total respondents
#       8 normalized_proportions = (high_income_respondents / total_respondents) * 100
#
# NameError: name 'seventy_five' is not defined

# %%
plt.figure(figsize=(48, 5))
normalized_proportions.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Proportion of High-Income Respondents by Municipality', fontsize=14)
plt.xlabel('Municipality', fontsize=12)
plt.ylabel('Percentage of High-Income Respondents (%)', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 plt.figure(figsize=(48, 5))
# ----> 2 normalized_proportions.plot(kind='bar', color='skyblue', edgecolor='black')
#       3 plt.title('Proportion of High-Income Respondents by Municipality', fontsize=14)
#       4 plt.xlabel('Municipality', fontsize=12)
#
# NameError: name 'normalized_proportions' is not defined

# %% [markdown]
# **Conclusion**
#
# After analyzing each municipalities proportional income these are the clear top 6
# - Kilbuck Township
# - Leet Township
# - Thornburg Borough
# - McDonald Borough
# - Crescent Township
# - Sewickley Heights Borough
